# %%
using LinearAlgebra
using FlexiMaps
using Plots
using LaTeXStrings
using DelimitedFiles 
using Integrals

# %% [markdown]
# **Noninteracting $H_{s}$**

# %%
Θ(x) = x >= 0 ? 1.0 : 0 #Heaviside step function
fermi_dirac_distribution(ε, μ, β) = 1/(exp((ε - μ)*β) + 1) #Fermi-Dirac distribution
J(ω, W = 8.0) = abs(ω) <= abs(W) ? W/8 : 0 #Spectral density Γ = W/8 in this case

#Other spectral densities just to play with Jeff:

J(ω, W = 8.0) = abs(ω) <= abs(W) ? -(ω^2) + 100 : 0 #Spectral density Γ = W/8 in this case
# J(ω, W = 8.0) = abs(ω) <= abs(W) ? (ω^2) : 0 #Spectral density Γ = W/8 in this case
# J(ω, W = 8.0) = abs(ω) <= abs(W) ? abs(cos(ω)) : 0 #Spectral density Γ = W/8 in this case
# Out:
# J (generic function with 2 methods)

# %%
function Logarithmic_linear_arrays(L, W = 8.0)

    D = 1 #Number of system sites
    R = L #Number of right-lead sites. We assume that both leads has the same size.
    
    M = D+L+R #total number of sites of system and lead

    #We need to define εk_array for each lead. In particular, we use the logarithmic-linear discretization of the paper.
    
    W_log = W #W
    W_lin = W_log/2 #W* = W/2
    
    L_log = L*0.2
    L_lin = L - L_log
    
    Lin_Window = LinRange(-W_lin, W_lin, Int(L_lin))
    Log_Window = maprange(log, W_lin, W_log, length=Int(L_log/2 + 1))
    
    εk_array = []
    append!(εk_array, -reverse( Log_Window[2:length(Log_Window)]), Lin_Window, Log_Window[2:length(Log_Window)])
    
    γk_array = [εk_array[k+1] - εk_array[k] for k=1:Int(L/2)]
    append!(γk_array, reverse(γk_array))

    Kp_array = [sqrt(J(εk_array[k])*γk_array[k]/(2*pi)) for k=1:L] #Kp = sqrt(J(e)*γ/(2*pi))

    return εk_array, γk_array, Kp_array
end

function J_eff(εk_array, γk_array, Kp_array, ω)
    Value = 0
    for i=1:length(εk_array) #1,...,L
        Value += (abs(Kp_array[i])^2)*γk_array[i]/((ω - εk_array[i])^2 + (γk_array[i]/2)^2)
    end
    return Value
end
# Out:
# J_eff (generic function with 1 method)

# %%
L = 20

εk_array, γk_array, Kp_array = Logarithmic_linear_arrays(L)
# Out:
# (Any[-8.0, -5.656854249492379, -4.0, -3.466666666666667, -2.9333333333333336, -2.4000000000000004, -1.866666666666667, -1.3333333333333337, -0.7999999999999998, -0.2666666666666666, 0.2666666666666666, 0.7999999999999998, 1.333333333333333, 1.8666666666666663, 2.4000000000000004, 2.9333333333333336, 3.466666666666667, 4.0, 5.656854249492379, 8.0], [2.343145750507621, 1.6568542494923788, 0.5333333333333332, 0.5333333333333332, 0.5333333333333332, 0.5333333333333334, 0.5333333333333332, 0.5333333333333339, 0.5333333333333332, 0.5333333333333332, 0.5333333333333332, 0.5333333333333332, 0.5333333333333339, 0.5333333333333332, 0.5333333333333334, 0.5333333333333332, 0.5333333333333332, 0.5333333333333332, 1.6568542494923788, 2.343145750507621], [3.6640464283098333, 4.23454424675049, 2.6702324712498178, 2.732793986222527, 2.785299930544558, 2.8283103872081385, 2.862253448076845, 2.887448902925653, 2.904124436783954, 2.9124263995825372, 2.9124263995825372, 2.904124436783954, 2.8874489029256
# ...

# %% [markdown]
# Let's compare $J_{eff}(\omega)$ (equation 17) vs $J(\omega)$ (equation 37).

# %%
W_lin = 4

ω_domain = LinRange(-20,20,1000)
J_effective = [J_eff(εk_array, γk_array, Kp_array, ω) for ω=ω_domain]
J_real = [J(ω) for ω=ω_domain]

plot(ω_domain, J_real, color = "black", label =  L"J(\omega)", linewidth = 1.5)
plot!(ω_domain, J_effective, color = "blue", label = L"J_{eff}(\omega)", linewidth = 1.5)
xlabel!(L"\omega")
title!(L"L = "*string(L))
vline!([-W_lin, W_lin], label = L"| \omega | \leq |W*| = "*string(W_lin), color = "red", linewidth = 1.5, linestyle = :dash)

# %%
function fk_arrays(εk_array, W = 8.0)

    μ_L, μ_R = W/16, -W/16
    β_L, β_R = 1/(W/8), 1/(W/8)
    
    fk_array_L = [fermi_dirac_distribution(ε, μ_L, β_L) for ε = εk_array]
    fk_array_R = [fermi_dirac_distribution(ε, μ_R, β_R) for ε = εk_array]
    
    return fk_array_L, fk_array_R
end

function Γ_plus_Γ_minus_Matrices(L, W = 8.0)
    
    εk_array, γk_array, Kp_array = Logarithmic_linear_arrays(L, W)
    fk_array_L, fk_array_R = fk_arrays(εk_array, W)

    D = 1
    M = Int(2*length(εk_array) + D) #L+D+R=2L+1
    
    Γ_plus = zeros(M,M) 
    Γ_minus = zeros(M,M)
    
    for i=1:L
        Γ_plus[i,i] = γk_array[i]*fk_array_L[i]
        Γ_minus[i,i] = γk_array[i]*(1 - fk_array_L[i])
    end
    
    for i=L+D+1:M #If R = 0, then L+D=M and the for is i = M+1:M.
        Γ_plus[i,i] = γk_array[i - (L + D)]*fk_array_R[i - (L + D)] #diag(γ1fL_1, ..., γLfL_L, 0, ..., 0,γ1fR_1, ..., γRfR_R)
        Γ_minus[i,i] = γk_array[i - (L + D)]*(1 - fk_array_R[i - (L + D)])
    end    

    return Γ_plus, Γ_minus
end

function Hamiltonian(ε, εk_array_L, εk_array_R, Kp_array_L,  Kp_array_R)
    M = length(εk_array_L) + 1 + length(εk_array_R) #L+D+R

    H_Matrix = zeros(ComplexF64, M, M)
    
    εi = []
    append!(εi, εk_array_L, ε, εk_array_R) 

    Kpi = []
    append!(Kpi, Kp_array_L, ε, Kp_array_R) 
    
    for i = 1:M
        H_Matrix[i,i] = εi[i]
        H_Matrix[i, length(εk_array_L) + 1] = Kpi[i]
        H_Matrix[length(εk_array_L) + 1, i] = conj(Kpi[i])
    end
        
    return H_Matrix
end

function Diagonalize_L_Generator(ε, εk_array, Kp_array, Γ_plus, Γ_minus)

    Λ = (Γ_minus + Γ_plus)/2
    Ω = (Γ_minus - Γ_plus)/2    
    
    M = size(Γ_minus)[1]
    L_Matrix = zeros(ComplexF64, 2*M, 2*M)

    H_Matrix = Hamiltonian(ε, εk_array, εk_array, Kp_array,  Kp_array)
    
    L_Matrix[1:M,1:M] = H_Matrix - 1im*Ω
    L_Matrix[1:M,M+1:2*M] = 1im*Γ_plus
    L_Matrix[M+1:2*M,1:M] = 1im*Γ_minus
    L_Matrix[M+1:2*M,M+1:2*M] = H_Matrix + 1im*Ω
    
    #Let's diagonalize L_Matrix
    
    Eigvals, V = eigen(L_Matrix)
    
    ε_matrix = zeros(Complex{Float64},2*M, 2*M)
    for i =1:2*M
        ε_matrix[i,i] = Eigvals[i]
    end
    
    #Let's check this diagonalization
    # println(isapprox(V*ε_matrix*inv(V), L_Matrix))

    return V, ε_matrix
end

function two_point_correlations(i,j, V, ε_matrix)
    V_inv = inv(V)
    
    correlation = 0
    for k = 1:size(V)[1]
            correlation += V[j,k]*Θ(imag(ε_matrix[k,k]))*V_inv[k,i] #Vjk*Dkl*Vinvli = Vjk*Θ(imag(ε_matrix[k,k]))*Vinvki because D is diagonal.
    end
    return correlation
end
# Out:
# two_point_correlations (generic function with 1 method)

# %%
function Particle_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)

    V, ε_matrix = Diagonalize_L_Generator(ε, εk_array, Kp_array, Γ_plus, Γ_minus)
    
    current = 0
    for i=1:length(fk_array_L)
        current += γk_array[i]*(fk_array_L[i] - two_point_correlations(i,i, V, ε_matrix))
    end

    return current
end

function Energy_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)

    V, ε_matrix = Diagonalize_L_Generator(ε, εk_array, Kp_array, Γ_plus, Γ_minus)
    
    L = length(fk_array_L)
    current = 0
    for i=1:L
        current += γk_array[i]*εk_array[i]*(fk_array_L[i] - two_point_correlations(i,i, V, ε_matrix))
        current -= 0.5*(γk_array[i]*Kp_array[i]*two_point_correlations(L+1,i, V, ε_matrix) + γk_array[i]*conj(Kp_array[i])*two_point_correlations(i, L+1, V, ε_matrix))
    end    

    return current
end
# Out:
# Energy_Current (generic function with 1 method)

# %% [markdown]
# Let's use these functions to reproduce figures 6 and 8.

# %%
W = 8
onsite_energies = LinRange(-1,1, 100)*W
# Out:
# 100-element LinRange{Float64, Int64}:
#  -8.0, -7.83838, -7.67677, -7.51515, …, 7.51515, 7.67677, 7.83838, 8.0

# %%
L = 10

εk_array, γk_array, Kp_array = Logarithmic_linear_arrays(L, W)
fk_array_L, fk_array_R = fk_arrays(εk_array, W)
Γ_plus, Γ_minus = Γ_plus_Γ_minus_Matrices(L, W)

Particle_Current(0.5*W, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array) 
Energy_Current(0.5*W, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)

JP_array_10 = [real(Particle_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)) for ε = onsite_energies]
JE_array_10 = [real(Energy_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)) for ε = onsite_energies]
# Out:
# 100-element Vector{Float64}:
#  -0.014285510483896119
#  -0.014680209001068922
#  -0.01509377143216567
#  -0.015528618069666322
#  -0.015987809689762156
#  -0.01647507977359791
#  -0.01699484042277194
#  -0.017552174296924655
#  -0.018152829251921243
#  -0.018803232023523686
#  -0.019510532934580216
#  -0.02028268684813836
#  -0.021128568023694505
#   ⋮
#   0.020282686848191282
#   0.019510532934677388
#   0.0188032320234958
#   0.018152829251999066
#   0.01755217429693752
#   0.016994840422730702
#   0.01647507977370361
#   0.01598780968979866
#   0.015528618069734957
#   0.015093771432167648
#   0.01468020900112791
#   0.014285510483849219

# %%
L = 20

εk_array, γk_array, Kp_array = Logarithmic_linear_arrays(L, W)
fk_array_L, fk_array_R = fk_arrays(εk_array, W)
Γ_plus, Γ_minus = Γ_plus_Γ_minus_Matrices(L, W)

JP_array_20 = [real(Particle_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)) for ε = onsite_energies]
JE_array_20 = [real(Energy_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)) for ε = onsite_energies]
# Out:
# 100-element Vector{Float64}:
#  -0.00876253905709036
#  -0.009110558020129222
#  -0.009477418647277136
#  -0.009864687963821728
#  -0.010275272679824615
#  -0.010713640945214618
#  -0.011185712960859823
#  -0.011698415891007827
#  -0.012259004344803835
#  -0.012874271973025327
#  -0.013549730578552563
#  -0.014288785806437082
#  -0.015091974954882424
#   ⋮
#   0.014288785806452901
#   0.01354973057855703
#   0.012874271972871
#   0.012259004344825023
#   0.011698415891018034
#   0.01118571296093796
#   0.010713640944955444
#   0.010275272679817368
#   0.009864687963938959
#   0.00947741864725981
#   0.00911055802022058
#   0.008762539057070626

# %%
# L = 50 #It took 40 minutes.

# εk_array, γk_array, Kp_array = Logarithmic_linear_arrays(L, W)
# fk_array_L, fk_array_R = fk_arrays(εk_array, W)
# Γ_plus, Γ_minus = Γ_plus_Γ_minus_Matrices(L, W)

# JP_array_50 = [real(Particle_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)) for ε = onsite_energies]
# JE_array_50 = [real(Energy_Current(ε, εk_array, Kp_array, Γ_plus, Γ_minus, fk_array_L, γk_array)) for ε = onsite_energies]   

# writedlm("JP_array_50.txt", JP_array_50)
# writedlm("JE_array_50.txt", JE_array_50)

# %%
JP_array_50 = readdlm("JP_array_50.txt")
JE_array_50 = readdlm("JE_array_50.txt")
# Out:
# 100×1 Matrix{Float64}:
#  -0.005353493871043611
#  -0.005684154723394898
#  -0.006047040902805823
#  -0.006442089366512648
#  -0.006868358049706102
#  -0.007325529054140065
#  -0.007815761728313051
#  -0.008344195696962658
#  -0.00891729619103138
#  -0.00954057113999623
#  -0.010217973291974864
#  -0.010953377521591708
#  -0.011752129947388185
#   ⋮
#   0.010953377521403417
#   0.010217973292085075
#   0.009540571140054192
#   0.008917296190991167
#   0.008344195696887654
#   0.007815761728323031
#   0.007325529054067782
#   0.006868358049677422
#   0.006442089366205142
#   0.006047040902630862
#   0.005684154723471707
#   0.005353493870933623

# %%
plot(onsite_energies/W, JP_array_10/W*100,color = "orange", label = "L = 10", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)
plot!(onsite_energies/W, JP_array_20/W*100,color = "teal", label = "L = 20", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)
plot!(onsite_energies/W, JP_array_50/W*100,color = "blue", label = "L = 50", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)

xlabel!("Single-level energy "*L"\epsilon / W")
ylabel!("Particle current "*L"J^{P}/W"*" ( "*L"\times 10^{-2}"*")")
vline!([-W_lin/W, W_lin/W], label = false, color = "black", linewidth = 1, linestyle = :dash)
annotate!(-0.5, 0.6, text("-W* ", :right))
annotate!(0.5, 0.6, text(" W*", :left))

# %%
plot(onsite_energies/W, JE_array_10/(W^2)*1000,color = "orange", label = "L = 10", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)
plot!(onsite_energies/W, JE_array_20/(W^2)*1000,color = "teal", label = "L = 20", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)
plot!(onsite_energies/W, JE_array_50/(W^2)*1000,color = "blue", label = "L = 50", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)

xlabel!("Single-level energy "*L"\epsilon / W")
ylabel!("Energy current "*L"J^{E}/ W^{2}"*" ( "*L"\times 10^{-3}"*")")
vline!([-W_lin/W, W_lin/W], label = false, color = "black", linewidth = 1, linestyle = :dash)
annotate!(-0.5, 0, text("-W* ", :right))
annotate!(0.5, 0, text(" W*", :left))

# %% [markdown]
# **Landauer-Buttiker Method:**

# %%
W = 8 

μ_L, μ_R = W/16, -W/16
β_L, β_R = 1/(W/8), 1/(W/8)

σ_plus = [0 1; 0 0]
σ_minus = [0 0; 1 0]
I = [1 0; 0 1]

function Particle_Current_LB_Integrand(ω, p)
    #p contains all the parameters that I need to define the integrand as a list.
    
    ε = p[1] 

    #First attempt:
    # n = σ_minus*σ_plus #Due to JW
    # HS = ε*n
    # M = I*ω - HS
    # # Transmission_Function = J(ω)^2/abs(det(M))^2
    
    Γ = J(ω)
    Transmission_Function = (Γ^2)/((ω-ε)^2 + 0.25*(2*Γ)^2) #From the book of A. Ryndyk
    return Transmission_Function*(fermi_dirac_distribution(ω, μ_L, β_L) - fermi_dirac_distribution(ω, μ_R, β_R))/(2*pi)
end

function Energy_Current_LB_Integrand(ω, p)
    ε = p[1]

    #First attempt:
    # n = σ_minus*σ_plus #Due to JW
    # HS = ε*n
    # M = I*ω - HS
    # # Transmission_Function = J(ω)^2/abs(det(M))^2
    
    Γ = J(ω)
    Transmission_Function = (Γ^2)/((ω-ε)^2 + 0.25*(2*Γ)^2)
    return ω*Transmission_Function*(fermi_dirac_distribution(ω, μ_L, β_L) - fermi_dirac_distribution(ω, μ_R, β_R))/(2*pi)
end
# Out:
# Energy_Current_LB_Integrand (generic function with 1 method)

# %%
domain = (-W,W)

Particle_Current_LB = []
Energy_Current_LB = []

for ε=onsite_energies
    
    prob = IntegralProblem(Particle_Current_LB_Integrand, domain, [ε])
    sol = solve(prob, HCubatureJL(); reltol = 1e-10, abstol = 1e-10)
    append!(Particle_Current_LB, sol.u)
    
    prob = IntegralProblem(Energy_Current_LB_Integrand, domain, [ε])
    sol = solve(prob, HCubatureJL(); reltol = 1e-10, abstol = 1e-10)
    append!(Energy_Current_LB, sol.u)

end

# %%
plot(onsite_energies/W, Particle_Current_LB/(W)*100, color = "black", label = "LB", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)
xlabel!("Single-level energy "*L"\epsilon / W")
ylabel!("Particle current "*L"J^{P}/W"*" ( "*L"\times 10^{-2}"*")")

# %%
plot(onsite_energies/W, Energy_Current_LB/(W^2)*1000, color = "black", label = "LB", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)
xlabel!("Single-level energy "*L"\epsilon / W")
ylabel!("Energy current "*L"J^{E}/ W^{2}"*" ( "*L"\times 10^{-3}"*")")

# %% [markdown]
# Finally,

# %%
plot(onsite_energies/W, JP_array_10/W*100,color = "orange", label = "L = 10", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)
plot!(onsite_energies/W, JP_array_20/W*100,color = "teal", label = "L = 20", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)
plot!(onsite_energies/W, JP_array_50/W*100,color = "blue", label = "L = 50", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)
plot!(onsite_energies/W, Particle_Current_LB/(W)*100, color = "black", label = "LB", linewidth = 1.5, xlims=(-1,1), ylims=(0,1.2), yticks=0:0.2:1.2)

xlabel!("Single-level energy "*L"\epsilon / W")
ylabel!("Particle current "*L"J^{P}/W"*" ( "*L"\times 10^{-2}"*")")
vline!([-W_lin/W, W_lin/W], label = false, color = "black", linewidth = 1, linestyle = :dash)
annotate!(-0.5, 0.6, text("-W* ", :right))
annotate!(0.5, 0.6, text(" W*", :left))

# %%
plot(onsite_energies/W, JE_array_10/(W^2)*1000,color = "orange", label = "L = 10", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)
plot!(onsite_energies/W, JE_array_20/(W^2)*1000,color = "teal", label = "L = 20", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)
plot!(onsite_energies/W, JE_array_50/(W^2)*1000,color = "blue", label = "L = 50", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)
plot!(onsite_energies/W, Energy_Current_LB/(W^2)*1000, color = "black", label = "LB", linewidth = 1.5, xlims=(-1,1), ylims=(-1,1), yticks=-1.0:0.5:1.0)

xlabel!("Single-level energy "*L"\epsilon / W")
ylabel!("Energy current "*L"J^{E}/ W^{2}"*" ( "*L"\times 10^{-3}"*")")
vline!([-W_lin/W, W_lin/W], label = false, color = "black", linewidth = 1, linestyle = :dash)
annotate!(-0.5, 0, text("-W* ", :right))
annotate!(0.5, 0, text(" W*", :left))
